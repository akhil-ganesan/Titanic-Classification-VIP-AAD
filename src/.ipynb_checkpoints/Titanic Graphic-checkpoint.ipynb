# %%
# Libraries
import random
import operator

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import model_selection
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics

from deap import algorithms
from deap import base
from deap import creator
from deap import tools
from deap import gp

train_data = pd.read_csv('data/train.csv')
test_data  = pd.read_csv('data/test.csv')

# By using a list w/ references, we can clean both datasets at once
data_cleaner = [train_data, test_data]

#preview data
print(train_data.info()) 
train_data.head()
test_data.head()

train_data = pd.read_csv('data/train.csv')
test_data  = pd.read_csv('data/test.csv')

# By using a list w/ references, we can clean both datasets at once
data_cleaner = [train_data, test_data]

#preview data
print (train_data.info()) 
train_data.head()
test_data.head()

for dataset in data_cleaner:    
    #complete missing age with median
    dataset['Age'].fillna(dataset['Age'].median(), inplace = True)

    #complete embarked with mode
    dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace = True)

    #complete missing fare with median
    dataset['Fare'].fillna(dataset['Fare'].median(), inplace = True)
    
    #delete the cabin feature/column and others previously stated to exclude in train dataset
    drop_column = ['Cabin', 'Ticket', 'Name']
    dataset.drop(drop_column, axis=1, inplace = True)
    dataset.set_index(keys=['PassengerId'], drop=True, inplace=True)

for dataset in data_cleaner:    
    #Discrete variables
    dataset['FamilySize'] = dataset ['SibSp'] + dataset['Parch'] + 1

    dataset['IsAlone'] = 1 #initialize to yes/1 is alone
    dataset['IsAlone'].loc[dataset['FamilySize'] > 1] = 0 # now update to no/0 if family size is greater than 1

label = LabelEncoder()
for dataset in data_cleaner:    
    dataset['Sex_Code'] = label.fit_transform(dataset['Sex'])

    columns_map = {'Sex': {'male': 0, 'female': 1}}
    dataset.replace(columns_map, inplace=True)


#define y variable aka target/outcome
Target = ['Survived']

#define x variables for original features aka feature selection
data_x = ['Sex','Pclass', 'Embarked','SibSp', 'Parch', 'Age', 'Fare', 'FamilySize', 'IsAlone']
data_xy =  Target + data_x

#encode embarking location to categories
train_data = pd.get_dummies(train_data[data_xy])
test_data = pd.get_dummies(test_data[data_x])

train_data['Embarked_C'] = train_data['Embarked_C'].astype(int)
train_data['Embarked_Q'] = train_data['Embarked_Q'].astype(int)
train_data['Embarked_S'] = train_data['Embarked_S'].astype(int)


X_train = train_data.loc[:, train_data.columns != 'Survived']
y_train = train_data.loc[:, 'Survived']

X_train, X_test, y_train, y_test = model_selection.train_test_split(X_train, y_train, test_size=0.33, random_state=10)

print(X_train.head())
print(y_train.head())

# Create individual minimizing 2 objectives (false positives & false negatives)
creator.create("FitnessMin", base.Fitness, weights=(-1.0,-1.0))
creator.create("Individual", gp.PrimitiveTree, fitness=creator.FitnessMin)

# Setup of evolution environment (adding primitives, terminals, etc.)
random.seed(25)

pset = gp.PrimitiveSet("MAIN", arity=11)
pset.addPrimitive(np.add, arity=2)
pset.addPrimitive(np.subtract, arity=2)
pset.addPrimitive(np.multiply, arity=2)
pset.addPrimitive(np.negative, arity=1)
# pset = PrimitiveSetTyped("main", [bool, float], float)
# pset.addPrimitive(operator.xor, [bool, bool], bool)
# pset.addPrimitive(operator.mul, [float, float], float)
# pset.addTerminal(3.0, float) # Constants
# pset.addTerminal(1, bool) # Constants
# pset.addEphemeralConstant(lambda: random.randint(-10, 10), int) # Constants

# Here, use the example renameArgument function calls for every column in the titanic input data besides survived
# Sex  Pclass  SibSp  Parch   Age    Fare  FamilySize  IsAlone, C, Q, S
pset.renameArguments(ARG0='Sex')
pset.renameArguments(ARG1='Pclass')
pset.renameArguments(ARG2='SibSp')
pset.renameArguments(ARG3='Parch')
pset.renameArguments(ARG4='Age')
pset.renameArguments(ARG5='Fare')
pset.renameArguments(ARG6='FamilySize')
pset.renameArguments(ARG7='IsAlone')
pset.renameArguments(ARG8='Embarked_C')
pset.renameArguments(ARG9='Embarked_Q')
pset.renameArguments(ARG10='Embarked_S')
# ...

toolbox = base.Toolbox()
toolbox.register("expr", gp.genHalfAndHalf, pset=pset, min_=1, max_=2)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.expr)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("compile", gp.compile, pset=pset)

# Evaluation Function; this will have a return value in the form of (False Positive Rate, False Negative Rate) 
def evaluatePredictor(individual, points, pset, labels=y_train):
    func = gp.compile(expr=individual, pset=pset)
    predictions = [1 if func(*point) > 0 else 0 for point in points]
    # Here, calculate the number of false positives & false negatives in predictions    
    tn, fp, fn, tp = metrics.confusion_matrix(labels, predictions).ravel()
    falsePosRate = fp / (fp + tn)
    falseNegRate = fn / (fn + tp)
    
    return falsePosRate, falseNegRate


toolbox.register("evaluate", evaluatePredictor, points=X_train.values, pset=pset) # After "points =" in this line, add the 
# processed titanic input data; Note points will have the same columns as the renameArguments calls above
toolbox.register("select", tools.selNSGA2)
toolbox.register("mate", gp.cxOnePoint)
toolbox.register("expr_mut", gp.genFull, min_=0, max_=2)
toolbox.register("mutate", gp.mutUniform, expr=toolbox.expr_mut, pset=pset)

# This controls the max depth our trees can build to; python limit is 91 levels; this sets it to 17
toolbox.decorate("mate", gp.staticLimit(key=operator.attrgetter("height"), max_value=17))
toolbox.decorate("mutate", gp.staticLimit(key=operator.attrgetter("height"), max_value=17))

# Main Evolutionary Loop

gen = range(100)
avg_list = []
max_list = []
min_list = []
hof = tools.ParetoFront()

# Change 300 to any number of individuals we want to model
pop = toolbox.population(n=200)

# Evaluate the entire population
fitnesses = list(map(toolbox.evaluate, pop))
for ind, fit in zip(pop, fitnesses):
    ind.fitness.values = fit

# Begin the evolution
for g in gen:
    print("-- Generation %i --" % g)

    # Select the next generation individuals
    offspring = toolbox.select(pop, len(pop))
    # Clone the selected individuals
    offspring = list(map(toolbox.clone, offspring))

    # Apply crossover and mutation on the offspring
    for child1, child2 in zip(offspring[::2], offspring[1::2]):
        if random.random() < 0.5:
            toolbox.mate(child1, child2)
            del child1.fitness.values
            del child2.fitness.values

    for mutant in offspring:
        if random.random() < 0.2:
            toolbox.mutate(mutant)
            del mutant.fitness.values

    # Evaluate the individuals with an invalid fitness
    invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
    fitnesses = map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit

    # Replace population
    pop[:] = offspring

    hof.update(pop)

    # Gather all the fitnesses in one list and print the stats
    fp_fit = [ind.fitness.values[0] for ind in pop]
    fn_fit = [ind.fitness.values[1] for ind in pop]

    fp_max = max(fp_fit)
    fn_max = max(fn_fit)
    fp_min = min(fp_fit)
    fn_min = min(fn_fit)
        

    print("  FPR Min %s" % fp_min)
    print("  FPR Max %s" % fp_max)
    print("  FNR Min %s" % fn_min)
    print("  FNR Max %s" % fn_max)
    print(f'  Average {(np.mean(fp_fit) + np.mean(fn_fit)) / 2.0}')

print("-- End of (successful) evolution --")

best_ind = tools.selBest(pop, 1)[0]
print("Best individual is %s, %s" % (best_ind, best_ind.fitness.values))

# I think this loop from Lab 2 should work fine with some tweaks since we can't use eaMuPlusLambda

##
##
## Definition of Pareto dominance
"""
def pareto_dominance(ind1, ind2):
    not_equal = False
    for value_1, value_2 in zip(ind1.fitness.values, ind2.fitness.values):
        if value_1 > value_2:
            return False
        elif value_1 < value_2:
            not_equal = True
    return not_equal
"""



#Use this function to compare individuals: dominators = [ind for ind in pop if pareto_dominance(ind, a_given_individual)]
#a_given_individual is a set aside individual that we compare every other individual to

#initialize population & pareto
"""
pop = toolbox.population(n=MU) MU = population size -> based on our data, every function that we create
hof = tools.ParetoFront()
"""

'''
# Create a new individual for [1, 0]
individual_1 = creator.Individual()  # Initialize with default genotype
individual_1.fitness.values = (1.0, 0.0)  # Set fitness to [1, 0]

# Create a new individual for [0, 1]
individual_2 = creator.Individual()  # Initialize with default genotype
individual_2.fitness.values = (0.0, 1.0)  # Set fitness to [0, 1]

hof.update([individual_1, individual_2])
'''

'''
plt.scatter(fitness_1, fitness_2, color='r')
plt.plot(fitness_1, fitness_2, color='r', drawstyle='steps-post')
plt.xlabel("Mean Squared Error")
plt.ylabel("Tree Size")
plt.title("Pareto Front")
plt.show()

f1 = np.array(fitness_1)
f2 = np.array(fitness_2)
'''
# Create a new individual for [1, 0]
#individual_1 = creator.Individual(None)  # Initialize with default genotype
#individual_1.fitness.values = (1.0, 0.0)  # Set fitness to [1, 0]

# Create a new individual for [0, 1]
#individual_2 = creator.Individual(None)  # Initialize with default genotype
#individual_2.fitness.values = (0.0, 1.0)  # Set fitness to [0, 1]

#hof.update([individual_1, individual_2])

fitness_1 = [ind.fitness.values[0] for ind in hof]
fitness_2 = [ind.fitness.values[1] for ind in hof]

fpr_hof = [ind.fitness.values[0] for ind in hof]
fnr_hof = [ind.fitness.values[1] for ind in hof]

fitness_1.append(1.0)
fitness_2.append(0)

# fitness_1.append(0)
# fitness_2.append(1.0)

fpr_hof.append(1.0)
fnr_hof.append(0)

fnr_hof.append(1.0)
fpr_hof.append(0)

plt.figure(figsize=(10, 7))

LTGP_fpr_hof = fpr_hof.copy()
LTGP_fnr_hof = fnr_hof.copy()

plt.scatter(fpr_hof, fnr_hof, color='r', label='Pareto Front', s=100)
sorted_indices = np.argsort(fpr_hof)
fpr_hof_sorted = np.array(fpr_hof)[sorted_indices]
fnr_hof_sorted = np.array(fnr_hof)[sorted_indices]
#plt.plot(fpr_hof_sorted, fnr_hof_sorted, color='r', linestyle='--')

LTGP_ft_1 = fitness_1.copy()
LTGP_ft_2 = fitness_2.copy()

plt.scatter(fitness_1, fitness_2, color='r')
plt.plot(fitness_1, fitness_2, color='r', drawstyle='steps-post')
plt.xlabel("False Positive Rate")
plt.ylabel("False Negative Rate")
plt.title("Pareto Front")
plt.show()

f1 = np.array(fitness_1)
f2 = np.array(fitness_2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:43: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Age'].fillna(dataset['Age'].median(), inplace = True)
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:46: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace = True)
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:49: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Fare'].fillna(dataset['Fare'].median(), inplace = True)
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:43: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Age'].fillna(dataset['Age'].median(), inplace = True)
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:46: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace = True)
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:49: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Fare'].fillna(dataset['Fare'].median(), inplace = True)
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:61: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataset['IsAlone'].loc[dataset['FamilySize'] > 1] = 0 # now update to no/0 if family size is greater than 1
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['IsAlone'].loc[dataset['FamilySize'] > 1] = 0 # now update to no/0 if family size is greater than 1
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:61: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataset['IsAlone'].loc[dataset['FamilySize'] > 1] = 0 # now update to no/0 if family size is greater than 1
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['IsAlone'].loc[dataset['FamilySize'] > 1] = 0 # now update to no/0 if family size is greater than 1
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:68: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset.replace(columns_map, inplace=True)
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_59136\682403811.py:68: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset.replace(columns_map, inplace=True)
#              Sex  Pclass  SibSp  Parch   Age    Fare  FamilySize  IsAlone  \
# PassengerId
# 464            0       2      0      0  48.0  13.000           1        1
# 160            0       3      8      2  28.0  69.550          11        0
# 48             1       3      0      0  28.0   7.750           1        1
# 403            1       3      1      0  21.0   9.825           2        0
# 619            1       2      2      1   4.0  39.000           4        0
#
#              Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# 464                   0           0           1
# 160                   0           0           1
# 48                    0           1           0
# 403                   0           0           1
# 619                   0           0           1
# PassengerId
# 464    0
# 160    0
# 48     1
# 403    0
# 619    1
# Name: Survived, dtype: int64
# -- Generation 0 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48977113750528145
# -- Generation 1 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4846206164029858
# -- Generation 2 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49075618515562647
# -- Generation 3 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4866491009811746
# -- Generation 4 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4849627951739355
# -- Generation 5 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48238263461809305
# -- Generation 6 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4886412022909723
# -- Generation 7 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4882423947232524
# -- Generation 8 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4829143584808225
# -- Generation 9 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48454937561616823
# -- Generation 10 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4807977911835125
# -- Generation 11 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4809807638139054
# -- Generation 12 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4814891906483264
# -- Generation 13 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48258532463264636
# -- Generation 14 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4823220153983381
# -- Generation 15 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48087912539317407
# -- Generation 16 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4792130064316229
# -- Generation 17 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4813066287967701
# -- Generation 18 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4861559316464016
# -- Generation 19 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48424088070982585
# -- Generation 20 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49459497206703906
# -- Generation 21 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48912480634711986
# -- Generation 22 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4904517980376508
# -- Generation 23 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4821800032862307
# -- Generation 24 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4882198605699263
# -- Generation 25 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4841563776348528
# -- Generation 26 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48627623116285623
# -- Generation 27 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4858609924416694
# -- Generation 28 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4929647669123515
# -- Generation 29 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4910161494765504
# -- Generation 30 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49529564339702364
# -- Generation 31 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.496670050701845
# -- Generation 32 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4810477794469744
# -- Generation 33 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4856574808694427
# -- Generation 34 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4811238322144501
# -- Generation 35 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4777104948124501
# -- Generation 36 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4854335477207643
# -- Generation 37 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.47894024928407114
# -- Generation 38 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4792408220271349
# -- Generation 39 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48863779869489704
# -- Generation 40 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49133332942115393
# -- Generation 41 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4895138725881415
# -- Generation 42 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48891255105394116
# -- Generation 43 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49404892962771696
# -- Generation 44 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4943931036101591
# -- Generation 45 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49655632364677715
# -- Generation 46 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4965904182902211
# -- Generation 47 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4909612811605089
# -- Generation 48 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49746619877001075
# -- Generation 49 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48990411248298205
# -- Generation 50 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4895739636636777
# -- Generation 51 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4876408384582883
# -- Generation 52 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49044264353786216
# -- Generation 53 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4893272029482184
# -- Generation 54 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4894980869442749
# -- Generation 55 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49533859912680156
# -- Generation 56 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49380211022956666
# -- Generation 57 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4913274611520586
# -- Generation 58 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4913259354020938
# -- Generation 59 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4934013661330454
# -- Generation 60 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49524734754236893
# -- Generation 61 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4899567508567673
# -- Generation 62 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4871873386225999
# -- Generation 63 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.47633937373832214
# -- Generation 64 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4820506079526783
# -- Generation 65 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.47749149100981175
# -- Generation 66 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4833801816816112
# -- Generation 67 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48861338669546023
# -- Generation 68 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4828252781559551
# -- Generation 69 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4776910708417445
# -- Generation 70 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.47778308530115954
# -- Generation 71 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4806333622834609
# -- Generation 72 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48302368433406884
# -- Generation 73 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4856705671095254
# -- Generation 74 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48890134265996904
# -- Generation 75 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4914217055537299
# -- Generation 76 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4913810971315901
# -- Generation 77 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49526512839772785
# -- Generation 78 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4972890357260223
# -- Generation 79 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49446158631050185
# -- Generation 80 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49131179287357407
# -- Generation 81 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4913706516126004
# -- Generation 82 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49123890897140987
# -- Generation 83 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4866623632693301
# -- Generation 84 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4901461785831651
# -- Generation 85 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.487888538096803
# -- Generation 86 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4905454556124126
# -- Generation 87 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48995076522229
# -- Generation 88 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48656506736772914
# -- Generation 89 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.481974027040984
# -- Generation 90 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.484178853105488
# -- Generation 91 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4826594995540116
# -- Generation 92 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4842588376132576
# -- Generation 93 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48725634946716123
# -- Generation 94 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.48965635416177644
# -- Generation 95 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.487621121074128
# -- Generation 96 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4842530280268532
# -- Generation 97 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.487197314680062
# -- Generation 98 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.4909719027275715
# -- Generation 99 --
#   FPR Min 0.0
#   FPR Max 1.0
#   FNR Min 0.0
#   FNR Max 1.0
#   Average 0.49043566029763863
# -- End of (successful) evolution --
# Best individual is negative(multiply(add(multiply(multiply(multiply(Embarked_S, Sex), multiply(FamilySize, Embarked_Q)), Embarked_S), Embarked_C), add(negative(add(add(Embarked_Q, FamilySize), multiply(negative(Fare), multiply(Sex, Embarked_Q)))), subtract(Age, SibSp)))), (0.0, 0.9789915966386554)

# %%
LTGP_fpr_hof = fpr_hof.copy()
LTGP_fnr_hof = fnr_hof.copy()

LTGP_ft_1 = fitness_1.copy()
LTGP_ft_2 = fitness_2.copy()

# %%
plt.scatter(LTGP_fpr_hof, LTGP_fnr_hof, color='b', label='LTGP Pareto Front', s=100)
sorted_indices = np.argsort(fpr_hof)
fpr_hof_sorted = np.array(fpr_hof)[sorted_indices]
fnr_hof_sorted = np.array(fnr_hof)[sorted_indices]
#plt.plot(fpr_hof_sorted, fnr_hof_sorted, color='r', linestyle='--')

plt.scatter(LTGP_ft_1, LTGP_ft_2, color='b')
plt.plot(LTGP_ft_1, LTGP_ft_2, color='b', linestyle='--', drawstyle='steps-post')
plt.xlabel("False Positive Rate")
plt.ylabel("False Negative Rate")
plt.title("Pareto Front")
plt.show()

# %%
# Libraries

import random
import operator

import numpy as np
import matplotlib.pyplot as plt

from deap import algorithms
from deap import base
from deap import creator
from deap import tools
from deap import gp

# Data Processing

#load packages
import sys #access to system parameters https://docs.python.org/3/library/sys.html
print("Python version: {}". format(sys.version))

import pandas as pd #collection of functions for data processing and analysis modeled after R dataframes with SQL like features
print("pandas version: {}". format(pd.__version__))

import matplotlib #collection of functions for scientific and publication-ready visualization
print("matplotlib version: {}". format(matplotlib.__version__))

import numpy as np #foundational package for scientific computing
print("NumPy version: {}". format(np.__version__))

import scipy as sp #collection of functions for scientific computing and advance mathematics
print("SciPy version: {}". format(sp.__version__)) 

import IPython
from IPython import display #pretty printing of dataframes in Jupyter notebook
print("IPython version: {}". format(IPython.__version__)) 

import sklearn #collection of machine learning algorithms
print("scikit-learn version: {}". format(sklearn.__version__))

#misc libraries
import random
import time


#ignore warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)

#Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from xgboost import XGBClassifier

#Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics

#Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.plotting import scatter_matrix

#Configure Visualization Defaults
#%matplotlib inline = show plots in Jupyter Notebook browser
# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')
pylab.rcParams['figure.figsize'] = 12,8

train_data = pd.read_csv('data/train.csv')
test_data  = pd.read_csv('data/test.csv')

# By using a list w/ references, we can clean both datasets at once
data_cleaner = [train_data, test_data]

#preview data
print (train_data.info()) 
train_data.head()
test_data.head()

print('Train columns with null values:\n', train_data.isnull().sum())
print("-"*10)

print('Test/Validation columns with null values:\n', test_data.isnull().sum())
print("-"*10)

###COMPLETING: complete or delete missing values in train and test/validation dataset
for dataset in data_cleaner:    
    #complete missing age with median
    dataset['Age'].fillna(dataset['Age'].median(), inplace = True)

    #complete embarked with mode
    dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace = True)

    #complete missing fare with median
    dataset['Fare'].fillna(dataset['Fare'].median(), inplace = True)
    
    #delete the cabin feature/column and others previously stated to exclude in train dataset
    drop_column = ['Cabin', 'Ticket', 'Name']
    dataset.drop(drop_column, axis=1, inplace = True)
    dataset.set_index(keys=['PassengerId'], drop=True, inplace=True)

print(train_data.isnull().sum())
print("-"*10)
print(test_data.isnull().sum())

###CREATE: Feature Engineering for train and test/validation dataset
for dataset in data_cleaner:    
    #Discrete variables
    dataset['FamilySize'] = dataset ['SibSp'] + dataset['Parch'] + 1

    dataset['IsAlone'] = 1 #initialize to yes/1 is alone
    dataset['IsAlone'].loc[dataset['FamilySize'] > 1] = 0 # now update to no/0 if family size is greater than 1

#preview data again
train_data.head()

#CONVERT: convert objects to category using Label Encoder for train and test/validation dataset

#define y variable aka target/outcome
Target = ['Survived']

#define x variables for original features aka feature selection
data_x = ['Sex','Pclass', 'Embarked','SibSp', 'Parch', 'Age', 'Fare', 'FamilySize', 'IsAlone']

#code categorical data
label = LabelEncoder()
for dataset in data_cleaner:    
    dataset['Sex_Code'] = label.fit_transform(dataset['Sex'])

    columns_map = {'Sex': {'male': True, 'female': False}, 'Survived': {1: True, 0: False}}
    dataset.replace(columns_map, inplace=True)
    
    for i in data_x:
        if i not in ('Sex', 'Embarked'):
            dataset[i] = dataset[i].astype(float)


data_xy =  Target + data_x

#encode embarking location to categories
train_data = pd.get_dummies(train_data[data_xy])
test_data = pd.get_dummies(test_data[data_x])


print('Train columns with null values: \n', train_data.isnull().sum())
print("-"*10)
print (train_data.info())
print("-"*10)

print('Test/Validation columns with null values: \n', train_data.isnull().sum())
print("-"*10)
print (train_data.info())
print("-"*10)

train_data.describe(include = 'all')

X_train = train_data.loc[:, train_data.columns != 'Survived']
y_train = train_data.loc[:, 'Survived']

X_train, X_test, y_train, y_test = model_selection.train_test_split(X_train, y_train, test_size=0.33, random_state=10)
random.seed(0)
print(X_train.head())
print(y_train.head())
print(test_data.head())

# MOGP Algorithm

# Create individual minimizing 2 objectives (false positives & false negatives)

creator.create("FitnessMin", base.Fitness, weights=(-1.0,-1.0))
creator.create("Individual", gp.PrimitiveTree, fitness=creator.FitnessMin)

# Setup of evolution environment (adding primitives, terminals, etc.)

random.seed(0)

# pset = gp.PrimitiveSet("MAIN", arity=1)
# pset.addPrimitive(np.add, arity=2)
# pset.addPrimitive(np.subtract, arity=2)
# pset.addPrimitive(np.multiply, arity=2)
# pset.addPrimitive(np.negative, arity=1)

# Use the following example if you want strongly-typed GP

pset = gp.PrimitiveSetTyped("main", [bool, float, float, float, float, float, float, float, bool, bool, bool], bool)
pset.addPrimitive(operator.not_, [bool], bool)
pset.addPrimitive(operator.xor, [bool, bool], bool)
pset.addPrimitive(operator.and_, [bool, bool], bool)
pset.addPrimitive(operator.or_, [bool, bool], bool)

pset.addPrimitive(np.add, [float, float], float)
pset.addPrimitive(np.subtract, [float, float], float)
pset.addPrimitive(np.multiply, [float, float], float)
pset.addPrimitive(np.divide, [float, float], float)
pset.addPrimitive(np.negative, [float], float)

# pset.addPrimitive(np.add, [int, float], float)
# pset.addPrimitive(np.subtract, [int, float], float)
# pset.addPrimitive(np.multiply, [int, float], float)
# pset.addPrimitive(np.divide, [int, float], float)

# pset.addPrimitive(np.add, [int, int], int)
# pset.addPrimitive(np.subtract, [int, int], int)
# pset.addPrimitive(np.multiply, [int, int], int)
# pset.addPrimitive(np.divide, [int, int], int)
# pset.addPrimitive(np.negative, [int], int)

pset.addPrimitive(np.greater, [float, float], bool)
pset.addPrimitive(np.less, [float, float], bool)
pset.addPrimitive(np.greater_equal, [float, float], bool)
pset.addPrimitive(np.less_equal, [float, float], bool)
pset.addPrimitive(np.equal, [float, float], bool)
pset.addPrimitive(np.not_equal, [float, float], bool)

# pset.addPrimitive(np.greater, [int, int], bool)
# pset.addPrimitive(np.less, [int, int], bool)
# pset.addPrimitive(np.greater_equal, [int, int], bool)
# pset.addPrimitive(np.less_equal, [int, int], bool)
# pset.addPrimitive(np.equal, [int, int], bool)
# pset.addPrimitive(np.not_equal, [int, int], bool)

pset.addTerminal(3.0, float) # Constants
pset.addTerminal(2, float) # Constants
pset.addTerminal(5, float) # Constants
pset.addTerminal(1, bool) # Constants
# pset.addEphemeralConstant(lambda: random.randint(-10, 10), int) # Constants

# Here, use the example renameArgument function calls for every column in the titanic input data besides survived
# pset.renameArguments(ARG0='x')
# pset.renameArguments(ARG1='x')
# ...

pset.renameArguments(ARG0='Sex')
pset.renameArguments(ARG1='Pclass')
pset.renameArguments(ARG2='SibSp')
pset.renameArguments(ARG3='Parch')
pset.renameArguments(ARG4='Age')
pset.renameArguments(ARG5='Fare')
pset.renameArguments(ARG6='FamilySize')
pset.renameArguments(ARG7='IsAlone')
pset.renameArguments(ARG8='Embarked_C')
pset.renameArguments(ARG9='Embarked_Q')
pset.renameArguments(ARG10='Embarked_S')

toolbox = base.Toolbox()
toolbox.register("expr", gp.genHalfAndHalf, pset=pset, min_=1, max_=2)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.expr)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("compile", gp.compile, pset=pset)

# Evaluation Function; this will have a return value in the form of (False Positive Rate, False Negative Rate) 
def evaluatePredictor(individual, x, y, pset):
    func = gp.compile(expr=individual, pset=pset)
#     print(x)
#     print(func)
#     for i in x:
#         print("printing")
#         print(i)
    predictions = [func(*i) for i in x]
    # Here, calculate the number of false positives & false negatives in predictions    
    falsePosRate = sum([1 if (0, 1)[predictions[i] > 0] != y[i] and y[i] == 0 else 0 for i in range(len(predictions))])
    falseNegRate = sum([1 if (0, 1)[predictions[i] > 0] != y[i] and y[i] == 1 else 0 for i in range(len(predictions))])
    
    return (falsePosRate, falseNegRate)


toolbox.register("evaluate", evaluatePredictor, x=X_train.values, y=y_train.values, pset=pset) # After "points =" in this line, add the 
# processed titanic input data; Note points will have the same columns as the renameArguments calls above
toolbox.register("select", tools.selNSGA2)
toolbox.register("mate", gp.cxOnePoint)
toolbox.register("expr_mut", gp.genFull, min_=0, max_=2)
toolbox.register("mutate", gp.mutUniform, expr=toolbox.expr_mut, pset=pset)

# This controls the max depth our trees can build to; python limit is 91 levels; this sets it to 17
toolbox.decorate("mate", gp.staticLimit(key=operator.attrgetter("height"), max_value=17))
toolbox.decorate("mutate", gp.staticLimit(key=operator.attrgetter("height"), max_value=17))

# Main Evolutionary Loop
# random.seed(25)

gen = range(100)
avg_list = []
max_list = []
min_list = []
hof = tools.ParetoFront()

# Change 300 to any number of individuals we want to model
pop = toolbox.population(n=200)

# Evaluate the entire population
fitnesses = list(map(toolbox.evaluate, pop))
for ind, fit in zip(pop, fitnesses):
    ind.fitness.values = fit

# Begin the evolution
for g in gen:
    print("-- Generation %i --" % g)

    # Select the next generation individuals
    offspring = toolbox.select(pop, len(pop))
    # Clone the selected individuals
    offspring = list(map(toolbox.clone, offspring))

    # Apply crossover and mutation on the offspring
    for child1, child2 in zip(offspring[::2], offspring[1::2]):
        if random.random() < 0.5:
            toolbox.mate(child1, child2)
            del child1.fitness.values
            del child2.fitness.values

    for mutant in offspring:
        if random.random() < 0.2:
            toolbox.mutate(mutant)
            del mutant.fitness.values

    # Evaluate the individuals with an invalid fitness
    invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
    fitnesses = map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit

    # Replace population
    pop[:] = offspring
    
    hof.update(pop)

    # Gather all the fitnesses in one list and print the stats
    fpfits = [ind.fitness.values[0] for ind in pop]
    fnfits = [ind.fitness.values[1] for ind in pop]

    length = len(pop)
    mean = sum(fpfits) / length
    sum2 = sum(x*x for x in fpfits)
    std = abs(sum2 / length - mean**2)**0.5
    g_max = max(fpfits)
    g_min = min(fpfits)
        
    avg_list.append(mean)
    max_list.append(g_max)
    min_list.append(g_min)

#     print("  Min FP %s" % g_min)
#     print("  Max FP %s" % g_max)
    print("  Avg FP %s" % mean)
#     print("  Std FP %s" % std)
    
    length = len(pop)
    mean = sum(fnfits) / length
    sum2 = sum(x*x for x in fnfits)
    std = abs(sum2 / length - mean**2)**0.5
    g_max = max(fnfits)
    g_min = min(fnfits)
        
    avg_list.append(mean)
    max_list.append(g_max)
    min_list.append(g_min)

#     print("  Min FN %s" % g_min)
#     print("  Max FN %s" % g_max)
    print("  Avg FN %s" % mean)
#     print("  Std FN %s" % std)

print("-- End of (successful) evolution --")

best_ind = tools.selBest(pop, 1)[0]
print("Best individual is %s, %s" % (best_ind, best_ind.fitness.values))

# I think this loop from Lab 2 should work fine with some tweaks since we can't use eaMuPlusLambda

##
##
## Definition of Pareto dominance
"""
def pareto_dominance(ind1, ind2):
    not_equal = False
    for value_1, value_2 in zip(ind1.fitness.values, ind2.fitness.values):
        if value_1 > value_2:
            return False
        elif value_1 < value_2:
            not_equal = True
    return not_equal
"""



#Use this function to compare individuals: dominators = [ind for ind in pop if pareto_dominance(ind, a_given_individual)]
#a_given_individual is a set aside individual that we compare every other individual to

#initialize population & pareto
"""
pop = toolbox.population(n=MU) MU = population size -> based on our data, every function that we create
hof = tools.ParetoFront()
"""

'''
# Create a new individual for [1, 0]
individual_1 = creator.Individual()  # Initialize with default genotype
individual_1.fitness.values = (1.0, 0.0)  # Set fitness to [1, 0]

# Create a new individual for [0, 1]
individual_2 = creator.Individual()  # Initialize with default genotype
individual_2.fitness.values = (0.0, 1.0)  # Set fitness to [0, 1]

hof.update([individual_1, individual_2])
'''

'''
plt.scatter(fitness_1, fitness_2, color='r')
plt.plot(fitness_1, fitness_2, color='r', drawstyle='steps-post')
plt.xlabel("Mean Squared Error")
plt.ylabel("Tree Size")
plt.title("Pareto Front")
plt.show()

f1 = np.array(fitness_1)
f2 = np.array(fitness_2)
'''
# Create a new individual for [1, 0]
#individual_1 = creator.Individual(None)  # Initialize with default genotype
#individual_1.fitness.values = (1.0, 0.0)  # Set fitness to [1, 0]

# Create a new individual for [0, 1]
#individual_2 = creator.Individual(None)  # Initialize with default genotype
#individual_2.fitness.values = (0.0, 1.0)  # Set fitness to [0, 1]

#hof.update([individual_1, individual_2])

totalNeg = sum([1 if i == False else 0 for i in y_train])
totalPos = sum([1 if i == True else 0 for i in y_train])

fitness_1 = [ind.fitness.values[0]/totalNeg for ind in hof]
fitness_2 = [ind.fitness.values[1]/totalPos for ind in hof]

fpr_hof = [ind.fitness.values[0]/totalNeg for ind in hof]
fnr_hof = [ind.fitness.values[1]/totalPos for ind in hof]



fitness_1.append(1.0)
fitness_2.append(0)

# fitness_2.append(1.0)
# fitness_1.append(0)

fpr_hof.append(1.0)
fnr_hof.append(0)

fnr_hof.append(1.0)
fpr_hof.append(0)

plt.figure(figsize=(10, 7))

STGP_fpr_hof = fpr_hof.copy()
STGP_fnr_hof = fnr_hof.copy()

plt.scatter(fpr_hof, fnr_hof, color='r', label='Pareto Front', s=100)
sorted_indices = np.argsort(fpr_hof)
fpr_hof_sorted = np.array(fpr_hof)[sorted_indices]
fnr_hof_sorted = np.array(fnr_hof)[sorted_indices]
#plt.plot(fpr_hof_sorted, fnr_hof_sorted, color='r', linestyle='--')

STGP_ft_1 = fitness_1.copy()
STGP_ft_2 = fitness_2.copy()

plt.scatter(fitness_1, fitness_2, color='r')
plt.plot(fitness_1, fitness_2, color='r', drawstyle='steps-post')
plt.xlabel("False Positive Rate")
plt.ylabel("False Negative Rate")
plt.title("Pareto Front")
plt.show()

f1 = np.array(fitness_1)
f2 = np.array(fitness_2)

print(totalNeg)
print(totalPos)
# Out:
# Python version: 3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:15:57) [MSC v.1916 64 bit (AMD64)]
# pandas version: 2.2.2
# matplotlib version: 3.7.2
# NumPy version: 1.25.2
# SciPy version: 1.11.1
# IPython version: 8.15.0
# scikit-learn version: 1.5.2
# -------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
# Train columns with null values:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# ----------
# Test/Validation columns with null values:
#  PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64
# ----------
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64
# ----------
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64
# Train columns with null values:
#  Survived      0
# Sex           0
# Pclass        0
# SibSp         0
# Parch         0
# Age           0
# Fare          0
# FamilySize    0
# IsAlone       0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64
# ----------
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    bool
#  1   Sex         891 non-null    bool
#  2   Pclass      891 non-null    float64
#  3   SibSp       891 non-null    float64
#  4   Parch       891 non-null    float64
#  5   Age         891 non-null    float64
#  6   Fare        891 non-null    float64
#  7   FamilySize  891 non-null    float64
#  8   IsAlone     891 non-null    float64
#  9   Embarked_C  891 non-null    bool
#  10  Embarked_Q  891 non-null    bool
#  11  Embarked_S  891 non-null    bool
# dtypes: bool(5), float64(7)
# memory usage: 60.0 KB
# None
# ----------
# Test/Validation columns with null values:
#  Survived      0
# Sex           0
# Pclass        0
# SibSp         0
# Parch         0
# Age           0
# Fare          0
# FamilySize    0
# IsAlone       0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64
# ----------
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    bool
#  1   Sex         891 non-null    bool
#  2   Pclass      891 non-null    float64
#  3   SibSp       891 non-null    float64
#  4   Parch       891 non-null    float64
#  5   Age         891 non-null    float64
#  6   Fare        891 non-null    float64
#  7   FamilySize  891 non-null    float64
#  8   IsAlone     891 non-null    float64
#  9   Embarked_C  891 non-null    bool
#  10  Embarked_Q  891 non-null    bool
#  11  Embarked_S  891 non-null    bool
# dtypes: bool(5), float64(7)
# memory usage: 60.0 KB
# None
# ----------
#                Sex  Pclass  SibSp  Parch   Age    Fare  FamilySize  IsAlone  \
# PassengerId
# 464           True     2.0    0.0    0.0  48.0  13.000         1.0      1.0
# 160           True     3.0    8.0    2.0  28.0  69.550        11.0      0.0
# 48           False     3.0    0.0    0.0  28.0   7.750         1.0      1.0
# 403          False     3.0    1.0    0.0  21.0   9.825         2.0      0.0
# 619          False     2.0    2.0    1.0   4.0  39.000         4.0      0.0
#
#              Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# 464               False       False        True
# 160               False       False        True
# 48                False        True       False
# 403               False       False        True
# 619               False       False        True
# PassengerId
# 464    False
# 160    False
# 48      True
# 403    False
# 619     True
# Name: Survived, dtype: bool
#                Sex  Pclass  SibSp  Parch   Age     Fare  FamilySize  IsAlone  \
# PassengerId
# 892           True     3.0    0.0    0.0  34.5   7.8292         1.0      1.0
# 893          False     3.0    1.0    0.0  47.0   7.0000         2.0      0.0
# 894           True     2.0    0.0    0.0  62.0   9.6875         1.0      1.0
# 895           True     3.0    0.0    0.0  27.0   8.6625         1.0      1.0
# 896          False     3.0    1.0    1.0  22.0  12.2875         3.0      0.0
#
#              Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# 892               False        True       False
# 893               False       False        True
# 894               False        True       False
# 895               False       False        True
# 896               False       False        True
# -- Generation 0 --
#   Avg FP 168.665
#   Avg FN 129.365
# -- Generation 1 --
#   Avg FP 174.17
#   Avg FN 125.735
# -- Generation 2 --
#   Avg FP 166.335
#   Avg FN 131.3
# -- Generation 3 --
#   Avg FP 185.365
#   Avg FN 123.51
# -- Generation 4 --
#   Avg FP 173.93
#   Avg FN 127.395
# -- Generation 5 --
#   Avg FP 176.435
#   Avg FN 126.935
# -- Generation 6 --
#   Avg FP 170.895
#   Avg FN 128.75
# -- Generation 7 --
#   Avg FP 183.605
#   Avg FN 122.58
# -- Generation 8 --
#   Avg FP 190.74
#   Avg FN 121.52
# -- Generation 9 --
#   Avg FP 180.855
#   Avg FN 122.485
# -- Generation 10 --
#   Avg FP 186.26
#   Avg FN 116.76
# -- Generation 11 --
#   Avg FP 172.105
#   Avg FN 126.495
# -- Generation 12 --
#   Avg FP 171.98
#   Avg FN 124.85
# -- Generation 13 --
#   Avg FP 170.075
#   Avg FN 123.8
# -- Generation 14 --
#   Avg FP 179.02
#   Avg FN 118.735
# -- Generation 15 --
#   Avg FP 180.1
#   Avg FN 118.23
# -- Generation 16 --
#   Avg FP 183.345
#   Avg FN 119.46
# -- Generation 17 --
#   Avg FP 173.605
#   Avg FN 126.79
# -- Generation 18 --
#   Avg FP 167.135
#   Avg FN 129.785
# -- Generation 19 --
#   Avg FP 163.9
#   Avg FN 131.75
# -- Generation 20 --
#   Avg FP 173.375
#   Avg FN 125.34
# -- Generation 21 --
#   Avg FP 178.93
#   Avg FN 122.41
# -- Generation 22 --
#   Avg FP 185.575
#   Avg FN 117.895
# -- Generation 23 --
#   Avg FP 170.71
#   Avg FN 127.49
# -- Generation 24 --
#   Avg FP 179.41
#   Avg FN 122.725
# -- Generation 25 --
#   Avg FP 166.485
#   Avg FN 132.49
# -- Generation 26 --
#   Avg FP 163.84
#   Avg FN 131.68
# -- Generation 27 --
#   Avg FP 157.915
#   Avg FN 133.06
# -- Generation 28 --
#   Avg FP 179.875
#   Avg FN 121.26
# -- Generation 29 --
#   Avg FP 176.605
#   Avg FN 125.9
# -- Generation 30 --
#   Avg FP 178.485
#   Avg FN 124.495
# -- Generation 31 --
#   Avg FP 173.225
#   Avg FN 129.365
# -- Generation 32 --
#   Avg FP 169.38
#   Avg FN 128.84
# -- Generation 33 --
#   Avg FP 178.325
#   Avg FN 125.13
# -- Generation 34 --
#   Avg FP 172.53
#   Avg FN 133.325
# -- Generation 35 --
#   Avg FP 179.015
#   Avg FN 130.88
# -- Generation 36 --
#   Avg FP 182.19
#   Avg FN 127.36
# -- Generation 37 --
#   Avg FP 181.56
#   Avg FN 124.535
# -- Generation 38 --
#   Avg FP 167.935
#   Avg FN 130.21
# -- Generation 39 --
#   Avg FP 164.14
#   Avg FN 130.62
# -- Generation 40 --
#   Avg FP 171.43
#   Avg FN 132.14
# -- Generation 41 --
#   Avg FP 181.6
#   Avg FN 123.64
# -- Generation 42 --
#   Avg FP 184.15
#   Avg FN 121.98
# -- Generation 43 --
#   Avg FP 185.31
#   Avg FN 117.805
# -- Generation 44 --
#   Avg FP 178.84
#   Avg FN 122.55
# -- Generation 45 --
#   Avg FP 170.905
#   Avg FN 124.855
# -- Generation 46 --
#   Avg FP 168.56
#   Avg FN 125.56
# -- Generation 47 --
#   Avg FP 152.645
#   Avg FN 134.77
# -- Generation 48 --
#   Avg FP 152.165
#   Avg FN 135.595
# -- Generation 49 --
#   Avg FP 156.495
#   Avg FN 134.855
# -- Generation 50 --
#   Avg FP 155.85
#   Avg FN 137.44
# -- Generation 51 --
#   Avg FP 153.24
#   Avg FN 138.07
# -- Generation 52 --
#   Avg FP 154.515
#   Avg FN 138.365
# -- Generation 53 --
#   Avg FP 164.26
#   Avg FN 130.015
# -- Generation 54 --
#   Avg FP 164.84
#   Avg FN 129.37
# -- Generation 55 --
#   Avg FP 163.46
#   Avg FN 130.0
# -- Generation 56 --
#   Avg FP 156.96
#   Avg FN 135.505
# -- Generation 57 --
#   Avg FP 161.375
#   Avg FN 133.27
# -- Generation 58 --
#   Avg FP 160.325
#   Avg FN 135.795
# -- Generation 59 --
#   Avg FP 162.445
#   Avg FN 133.77
# -- Generation 60 --
#   Avg FP 163.375
#   Avg FN 133.415
# -- Generation 61 --
#   Avg FP 165.37
#   Avg FN 132.43
# -- Generation 62 --
#   Avg FP 165.99
#   Avg FN 128.15
# -- Generation 63 --
#   Avg FP 176.785
#   Avg FN 122.465
# -- Generation 64 --
#   Avg FP 175.2
#   Avg FN 123.665
# -- Generation 65 --
#   Avg FP 171.36
#   Avg FN 125.325
# -- Generation 66 --
#   Avg FP 167.21
#   Avg FN 129.905
# -- Generation 67 --
#   Avg FP 179.95
#   Avg FN 123.54
# -- Generation 68 --
#   Avg FP 178.385
#   Avg FN 123.12
# -- Generation 69 --
#   Avg FP 173.99
#   Avg FN 124.99
# -- Generation 70 --
#   Avg FP 165.095
#   Avg FN 128.13
# -- Generation 71 --
#   Avg FP 169.365
#   Avg FN 128.23
# -- Generation 72 --
#   Avg FP 169.395
#   Avg FN 127.79
# -- Generation 73 --
#   Avg FP 163.92
#   Avg FN 131.275
# -- Generation 74 --
#   Avg FP 170.415
#   Avg FN 129.63
# -- Generation 75 --
#   Avg FP 181.82
#   Avg FN 120.77
# -- Generation 76 --
#   Avg FP 192.745
#   Avg FN 113.7
# -- Generation 77 --
#   Avg FP 176.385
#   Avg FN 123.715
# -- Generation 78 --
#   Avg FP 174.45
#   Avg FN 124.06
# -- Generation 79 --
#   Avg FP 180.18
#   Avg FN 122.225
# -- Generation 80 --
#   Avg FP 187.495
#   Avg FN 119.26
# -- Generation 81 --
#   Avg FP 165.365
#   Avg FN 127.07
# -- Generation 82 --
#   Avg FP 159.4
#   Avg FN 130.405
# -- Generation 83 --
#   Avg FP 160.265
#   Avg FN 130.885
# -- Generation 84 --
#   Avg FP 166.23
#   Avg FN 131.685
# -- Generation 85 --
#   Avg FP 154.145
#   Avg FN 138.88
# -- Generation 86 --
#   Avg FP 162.705
#   Avg FN 136.135
# -- Generation 87 --
#   Avg FP 154.01
#   Avg FN 141.76
# -- Generation 88 --
#   Avg FP 146.425
#   Avg FN 143.605
# -- Generation 89 --
#   Avg FP 138.32
#   Avg FN 146.045
# -- Generation 90 --
#   Avg FP 136.76
#   Avg FN 150.745
# -- Generation 91 --
#   Avg FP 147.52
#   Avg FN 143.745
# -- Generation 92 --
#   Avg FP 144.54
#   Avg FN 144.51
# -- Generation 93 --
#   Avg FP 151.6
#   Avg FN 141.915
# -- Generation 94 --
#   Avg FP 148.905
#   Avg FN 142.165
# -- Generation 95 --
#   Avg FP 142.12
#   Avg FN 149.2
# -- Generation 96 --
#   Avg FP 142.885
#   Avg FN 144.595
# -- Generation 97 --
#   Avg FP 156.78
#   Avg FN 135.23
# -- Generation 98 --
#   Avg FP 158.39
#   Avg FN 136.51
# -- Generation 99 --
#   Avg FP 156.945
#   Avg FN 135.96
# -- End of (successful) evolution --
# Best individual is and_(equal(Pclass, Age), and_(or_(less(negative(Age), divide(IsAlone, Parch)), Embarked_S), xor(less_equal(2, divide(negative(5), multiply(Age, FamilySize))), Embarked_S))), (0.0, 235.0)
# 358
# 238

# %%
STGP_fpr_hof.remove(0)

# %%
STGP_fnr_hof.remove(1)

# %%
STGP_fnr_hof.remove(0)
STGP_fpr_hof.remove(1)

STGP_ft_1.remove(1)
STGP_ft_2.remove(0)

# %%
print([(STGP_ft_1[k], v) for k, v in enumerate(STGP_ft_2)])
# Out:
# [(0.0, 0.8949579831932774), (0.0111731843575419, 0.8319327731092437), (0.0111731843575419, 0.8319327731092437), (0.025139664804469275, 0.7478991596638656), (0.025139664804469275, 0.7478991596638656), (0.025139664804469275, 0.7478991596638656), (0.025139664804469275, 0.7478991596638656), (0.08100558659217877, 0.5462184873949579), (0.13687150837988826, 0.48739495798319327), (0.13687150837988826, 0.48739495798319327), (0.13966480446927373, 0.31932773109243695), (0.13966480446927373, 0.31932773109243695), (0.13966480446927373, 0.31932773109243695), (0.14804469273743018, 0.31512605042016806), (0.14804469273743018, 0.31512605042016806), (0.15083798882681565, 0.31092436974789917), (0.15363128491620112, 0.3025210084033613), (0.26536312849162014, 0.24369747899159663), (0.2709497206703911, 0.226890756302
804469273743018, 0.31512605042016806), (0.15083798882681565, 0.31092436974789917), (0.15363128491620112, 0.3025210084033613), (0.26536312849162014, 0.24369747899159663), (0.2709497206703911, 0.226890756302521), (0.3743016759776536, 0.20168067226890757), (0.5726256983240223, 0.18907563025210083), (0.5837988826815642, 0.18487394957983194), (0.6731843575418994, 0.16806722689075632), (0.6759776536312849, 0.13865546218487396), (0.7430167597765364, 0.08403361344537816), (0.7988826815642458, 0.058823529411764705), (0.8575418994413407, 0.05042016806722689), (0.8659217877094972, 0.012605042016806723), (0.8994413407821229, 0.008403361344537815), (0.8994413407821229, 0.008403361344537815), (0.9413407821229051, 0.0), (0.9413407821229051, 0.0), (0.9413407821229051, 0.0), (0.9413407821229051, 0.0), (0.9413407821229051, 0.0), (0.9413407821229051, 0.0), (0.9413407821229051, 0.0)]
# [(0.8949579831932774, 0.0), (0.8319327731092437, 0.0111731843575419), (0.8319327731092437, 0.0111731843575419), (0.7478991596638656, 0.025139664804469275), (0.7478991596638656, 0.025139664804469275), (0.7478991596638656, 0.025139664804469275), (0.7478991596638656, 0.025139664804469275), (0.5462184873949579, 0.08100558659217877), (0.48739495798319327, 0.13687150837988826), (0.48739495798319327, 0.13687150837988826), (0.31932773109243695, 0.13966480446927373), (0.31932773109243695, 0.13966480446927373), (0.31932773109243695, 0.13966480446927373), (0.31512605042016806, 0.14804469273743018), (0.31512605042016806, 0.14804469273743018), (0.31092436974789917, 0.15083798882681565), (0.3025210084033613, 0.15363128491620112), (0.24369747899159663, 0.26536312849162014), (0.226890756302521, 0.2709497206703911), (0.20168067226890757, 0.3743016759776536), (0.18907563025210083, 0.5726256983240223), (0.18487394957983194, 0.5837988826815642), (0.16806722689075632, 0.6731843575418994), (0.13865546218487396, 0.6759776536312849), (0.08403361344537816, 0.7430167597765364), (0.058823529411764705, 0.7988826815642458), (0.05042016806722689, 0.8575418994413407), (0.012605042016806723, 0.8659217877094972), (0.008403361344537815, 0.8994413407821229), (0.008403361344537815, 0.8994413407821229), (0.0, 0.9413407821229051), (0.0, 0.9413407821229051), (0.0, 0.9413407821229051), (0.0, 0.9413407821229051), (0.0, 0.9413407821229051), (0.0, 0.9413407821229051), (0.0, 0.9413407821229051)]

# %%
plt.scatter(STGP_fpr_hof, STGP_fnr_hof, color='', label='LTGP Pareto Front', s=100)
plt.scatter(STGP_ft_1, STGP_ft_2, color='r')
plt.plot(STGP_ft_1, STGP_ft_2, color='r', linestyle='--', drawstyle='steps-post')
plt.xlabel("False Positive Rate")
plt.ylabel("False Negative Rate")
plt.title("Pareto Front")
plt.show()

# %%
print([(LTGP_ft_1[k], v) for k, v in enumerate(LTGP_ft_2)])
print([(LTGP_fnr_hof[k], v) for k, v in enumerate(LTGP_fpr_hof)])
# Out:
# %%
print(totalNeg)
print(totalPos)

STGP_FN = [i * 100 for i in STGP_fnr_hof]
STGP_FP = [i * 100 for i in STGP_fpr_hof]


LTGP_FN = [i * 100 for i in LTGP_fnr_hof]
LTGP_FP = [i * 100 for i in LTGP_fpr_hof]
# STGP_F1 = [i * totalPos for i in STGP_fnr_hof]
# STGP_F2 = [i * totalNeg for i in STGP_fpr_hof]
# Out:
# 358
# 238

# %%
plt.scatter(LTGP_FP, LTGP_FN, color='m', label='LTGP', s=100)
# sorted_indices = np.argsort(fpr_hof)
# fpr_hof_sorted = np.array(fpr_hof)[sorted_indices]
# fnr_hof_sorted = np.array(fnr_hof)[sorted_indices]
#plt.plot(fpr_hof_sorted, fnr_hof_sorted, color='r', linestyle='--')

plt.scatter(LTGP_FP, LTGP_FN, color='m')
plt.plot(LTGP_FP, LTGP_FN, color='m', drawstyle='steps-post') #  linestyle='--'
plt.xlabel("False Positive Rate (%)")
plt.ylabel("False Negative Rate (%)")
plt.title("Pareto Front")

plt.scatter(STGP_FP, STGP_FN, color='g', label='STGP', s=100)
plt.scatter(STGP_FP, STGP_FN, color='g')
plt.plot(STGP_FP, STGP_FN, color='g', drawstyle='steps-post') #  linestyle='--'

plt.legend()


plt.show()

# %%
plt.scatter(LTGP_FP, LTGP_FN, color='m', label='LTGP', s=100)
plt.scatter(LTGP_FP, LTGP_FN, color='m')
plt.plot(LTGP_FP, LTGP_FN, color='m', drawstyle='steps-post') #  linestyle='--'

plt.scatter(STGP_FP, STGP_FN, color='g', label='STGP', s=100)
plt.scatter(STGP_FP, STGP_FN, color='g')
plt.plot(STGP_FP, STGP_FN, color='g', drawstyle='steps-post') #  linestyle='--'

ML_FP = [0.06108597285, 0.133, 0, 1] # 22.0 / totalNeg # 22.0 / (22 + 169)
ML_FN = [0.2450980392, 0.22, 1, 0] # 31.0 / totalPos # 31.0 / (31 + 73)

ML_FP = [i * 100 for i in ML_FP]
ML_FN = [i * 100 for i in ML_FN]

sorted_indices = np.argsort(ML_FP)
ML_FP = np.array(ML_FP)[sorted_indices]
ML_FN = np.array(ML_FN)[sorted_indices]

plt.scatter(ML_FP, ML_FN, color='c', label='ML', s=100)
plt.scatter(ML_FP, ML_FN, color='c')
plt.plot(ML_FP, ML_FN, color='c', drawstyle='steps-post')

plt.xlabel("False Positive Rate (%)")
plt.ylabel("False Negative Rate (%)")
plt.title("Pareto Front")

plt.legend()
plt.show()

# %%
# Read the CSV file
df = pd.read_csv('EmadeData.csv')

# Extract the columns as lists
EMADE_FN = df['False Negative Rate'].tolist()
EMADE_FP = df['False Positive Rate'].tolist()

# Display the lists
print("False Negative Rate:", EMADE_FN)
print("False Positive Rate:", EMADE_FP)
# Out:
# False Negative Rate: [14.0, 5.0, 17.0, 31.0, 0.0, 15.0, 62.0, 6.0, 3.0, 27.0, 5.2, 13.0, 5.0, 26.0, 39.0, 5.0, 21.0, 2.0, 18.0, 9.0, 18.0, 30.0, 0.0, 2.0, 22.0, 11.0, 62.0, 25.0, 9.0, 20.0, 19.0, 12.0, 13.0, 17.0, 8.0, 5.0, 6.0, 0.0, 1.0, 18.0, 3.0, 5.0, 0.0, 10.0, 37.0, 56.0, 10.0, 4.0, 39.0, 14.0, 48.0, 29.0, 16.0, 1.0, 55.0, 14.0, 21.0]
# False Positive Rate: [8.0, 85.0, 10.0, 1.0, 115.0, 10.0, 114.0, 31.0, 114.0, 2.0, 78.2, 14.0, 75.8, 5.0, 5.0, 65.0, 5.0, 91.0, 6.0, 20.0, 9.0, 1.0, 116.0, 99.0, 116.0, 15.0, 0.0, 3.0, 18.0, 8.0, 9.0, 14.0, 12.0, 9.0, 20.0, 64.0, 27.0, 109.0, 94.0, 10.0, 86.0, 66.0, 106.0, 17.0, 0.0, 0.0, 16.0, 78.0, 0.0, 11.0, 0.0, 1.0, 10.0, 101.0, 0.0, 18.0, 6.0]

# %%
# Function to find the Pareto frontier
def pareto_frontier(fn, fp):
    # Create an array to keep track of whether each individual is dominated
    is_dominated = np.zeros(len(fn), dtype=bool)

    # Compare each individual with every other individual
    for i in range(len(fn)):
        for j in range(len(fn)):
            if i != j:
                # Check if individual j dominates individual i
                if fn[j] <= fn[i] and fp[j] <= fp[i]:
                    is_dominated[i] = True
                    break

    # Return the indices of non-dominated individuals
    indices = np.where(~is_dominated)[0]
    
    return fn[indices], fp[indices]

EMADE_FN, EMADE_FP = pareto_frontier(EMADE_FN, EMADE_FP)


sorted_indices_2 = np.argsort(EMADE_FP)
EMADE_FP = np.array(EMADE_FP)[sorted_indices_2]
EMADE_FN = np.array(EMADE_FN)[sorted_indices_2]

plt.scatter(EMADE_FP, EMADE_FN, color='c', label='EMADE', s=100)
plt.scatter(EMADE_FP, EMADE_FN, color='c')
plt.plot(EMADE_FP, EMADE_FN, color='c', drawstyle='steps-post')

plt.xlabel("False Positive Rate (%)")
plt.ylabel("False Negative Rate (%)")
plt.title("Pareto Front")

plt.legend()
plt.show()

# %%
plt.scatter(LTGP_FP, LTGP_FN, color='m', label='LTGP', s=100)
plt.scatter(LTGP_FP, LTGP_FN, color='m')
plt.plot(LTGP_FP, LTGP_FN, color='m', drawstyle='steps-post') #  linestyle='--'

plt.scatter(STGP_FP, STGP_FN, color='g', label='STGP', s=100)
plt.scatter(STGP_FP, STGP_FN, color='g')
plt.plot(STGP_FP, STGP_FN, color='g', drawstyle='steps-post') #  linestyle='--'

plt.scatter(ML_FP, ML_FN, color='c', label='ML', s=100)
plt.scatter(ML_FP, ML_FN, color='c')
plt.plot(ML_FP, ML_FN, color='c', drawstyle='steps-post')

plt.scatter(EMADE_FP, EMADE_FN, color='r', label='EMADE', s=100)
plt.scatter(EMADE_FP, EMADE_FN, color='r')
plt.plot(EMADE_FP, EMADE_FN, color='r', drawstyle='steps-post')

plt.xlabel("False Positive Rate (%)")
plt.ylabel("False Negative Rate (%)")
plt.title("Pareto Front")

plt.legend()
plt.show()
